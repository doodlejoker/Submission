# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Arindam Baruah**
# Currently, i am a student.

# %% [markdown]
# *Data science is instresting because its all about playing with numbers and bringing them to a simpler and understanable form. Being a data scientise is fun and every industry or organisation needs one. So,  we will always be in trend.*

# %% [markdown]
# ### Adding two numbers in Python

# %%
x = input("Type a number: ")
y = input("Type another number: ")

sum = int(x) + int(y)

print("The sum is: ", sum)
# Out:
# Type a number: 1
# Type another number: 2
# The sum is:  3

# %% [markdown]
# * Hello, i am Arindam.<hr/> * I am learning in coursera.<hr/> * I course is about data science.<hr/>
# [This is a link to coursera](https://www.coursera.org/professional-certificates/ibm-data-science)
